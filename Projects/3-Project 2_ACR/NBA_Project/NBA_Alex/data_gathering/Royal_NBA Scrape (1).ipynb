# %%
import os
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
# get cURL address
headers = {
    'X-NewRelic-ID': 'VQECWF5UChAHUlNTBwgBVw==',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'Referer': 'https://stats.nba.com/players/boxscores-traditional/?sort=PLAYER_NAME&dir=1',
    'Connection': 'keep-alive',
    'x-nba-stats-origin': 'stats',
}

params = (
    ('DateFrom', ''),
    ('DateTo', ''),
    ('GameSegment', ''),
    ('LastNGames', '0'),
    ('LeagueID', '00'),
    ('Location', ''),
    ('MeasureType', 'Base'),
    ('Month', '0'),
    ('OpponentTeamID', '0'),
    ('Outcome', ''),
    ('PORound', '0'),
    ('PaceAdjust', 'N'),
    ('PerMode', 'Totals'),
    ('Period', '0'),
    ('PlusMinus', 'N'),
    ('Rank', 'N'),
    ('Season', '2018-19'),
    ('SeasonSegment', ''),
    ('SeasonType', 'Regular Season'),
    ('ShotClockRange', ''),
    ('VsConference', ''),
    ('VsDivision', ''),
)


# where angularjs is going
response = requests.get('https://stats.nba.com/stats/playergamelogs', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://stats.nba.com/stats/playergamelogs?DateFrom=&DateTo=&GameSegment=&LastNGames=0&LeagueID=00&Location=&MeasureType=Base&Month=0&OpponentTeamID=0&Outcome=&PORound=0&PaceAdjust=N&PerMode=Totals&Period=0&PlusMinus=N&Rank=N&Season=2018-19&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&VsConference=&VsDivision=', headers=headers, cookies=cookies)

# %%
results = response.json().get('resultSets')
len(results[0])
# Out:
# 3

# %%
results[0].get('headers')
# Out:
# ['SEASON_YEAR',
#  'PLAYER_ID',
#  'PLAYER_NAME',
#  'TEAM_ID',
#  'TEAM_ABBREVIATION',
#  'TEAM_NAME',
#  'GAME_ID',
#  'GAME_DATE',
#  'MATCHUP',
#  'WL',
#  'MIN',
#  'FGM',
#  'FGA',
#  'FG_PCT',
#  'FG3M',
#  'FG3A',
#  'FG3_PCT',
#  'FTM',
#  'FTA',
#  'FT_PCT',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'TOV',
#  'STL',
#  'BLK',
#  'BLKA',
#  'PF',
#  'PFD',
#  'PTS',
#  'PLUS_MINUS',
#  'NBA_FANTASY_PTS',
#  'DD2',
#  'TD3',
#  'GP_RANK',
#  'W_RANK',
#  'L_RANK',
#  'W_PCT_RANK',
#  'MIN_RANK',
#  'FGM_RANK',
#  'FGA_RANK',
#  'FG_PCT_RANK',
#  'FG3M_RANK',
#  'FG3A_RANK',
#  'FG3_PCT_RANK',
#  'FTM_RANK',
#  'FTA_RANK',
#  'FT_PCT_RANK',
#  'OREB_RANK',
#  'DREB_RANK',
#  'REB_RANK',
#  'AST_RANK',
#  'TOV_RANK',
#  'STL_RANK',
#  'BLK_RANK',
#  'BLKA_RANK',
#  'PF_RANK',
#  'PFD_RANK',
#  'PTS_RANK',
#  'PLUS_MINUS_RANK',
#  'NBA_FANTASY_PTS_RANK',
#  'DD2_RANK',
#  'TD3_RANK']

# %%
results[0].keys()
# Out:
# dict_keys(['name', 'headers', 'rowSet'])

# %%
df = pd.DataFrame.from_records(results[0].get('rowSet'))
df.columns = results[0].get('headers')
df.head()
# Out:
#   SEASON_YEAR  PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0     2018-19    1626143      Jahlil Okafor  1610612740               NOP
# 1     2018-19    1626145         Tyus Jones  1610612750               MIN
# 2     2018-19     201609       Goran Dragic  1610612748               MIA
# 3     2018-19     203915  Spencer Dinwiddie  1610612751               BKN
# 4     2018-19     202718   Chandler Parsons  1610612763               MEM
#
#                 TEAM_NAME     GAME_ID            GAME_DATE      MATCHUP WL  \
# 0    New Orleans Pelicans  0021801171  2019-04-03T00:00:00  NOP vs. CHA  L
# 1  Minnesota Timberwolves  0021801172  2019-04-03T00:00:00    MIN @ DAL  W
# 2              Miami Heat  0021801170  2019-04-03T00:00:00  MIA vs. BOS  L
# 3           Brooklyn Nets  0021801169  2019-04-03T00:00:00  BKN vs. TOR  L
# 4       Memphis Grizzlies  0021801175  2019-04-03T00:00:00    MEM @ POR  L
#
#      ...     STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0    ...        11650       822          1    16329      7651     12814
# 1    ...        11650      7964          1    10610     12127      6057
# 2    ...         4382      7964      22617    16329      1004      9633
# 3    ...        11650      7964          1    10610      4707      6871
# 4    ...         1414      2483          1     4611      7651      5338
#
#    PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK
# 0             5888                 12464      2246       118
# 1             3721                  8781      2246       118
# 2            15545                 10831      2246       118
# 3            15545                  8724      2246       118
# 4            23380                  7950      2246       118
#
# [5 rows x 64 columns]

# %%
df.shape
# Out:
# (24973, 64)

# %%
df.iloc[0]
# Out:
# SEASON_YEAR                          2018-19
# PLAYER_ID                            1626143
# PLAYER_NAME                    Jahlil Okafor
# TEAM_ID                           1610612740
# TEAM_ABBREVIATION                        NOP
# TEAM_NAME               New Orleans Pelicans
# GAME_ID                           0021801171
# GAME_DATE                2019-04-03T00:00:00
# MATCHUP                          NOP vs. CHA
# WL                                         L
# MIN                                  22.9167
# FGM                                        3
# FGA                                        4
# FG_PCT                                  0.75
# FG3M                                       0
# FG3A                                       0
# FG3_PCT                                    0
# FTM                                        2
# FTA                                        2
# FT_PCT                                     1
# OREB                                       1
# DREB                                       6
# REB                                        7
# AST                                        0
# TOV                                        3
# STL                                        0
# BLK                                        2
# BLKA                                       0
# PF                                         3
# PFD                                        2
#                                 ...
# TD3                                        0
# GP_RANK                                    1
# W_RANK                                 12502
# L_RANK                                 12502
# W_PCT_RANK                             12502
# MIN_RANK                               13103
# FGM_RANK                               11726
# FGA_RANK                               17773
# FG_PCT_RANK                             1776
# FG3M_RANK                              13063
# FG3A_RANK                              19237
# FG3_PCT_RANK                           13063
# FTM_RANK                                6182
# FTA_RANK                                7767
# FT_PCT_RANK                                1
# OREB_RANK                               6022
# DREB_RANK                               3103
# REB_RANK                                3973
# AST_RANK                               18422
# TOV_RANK                                1853
# STL_RANK                               11650
# BLK_RANK                                 822
# BLKA_RANK                                  1
# PF_RANK                                16329
# PFD_RANK                                7651
# PTS_RANK                               12814
# PLUS_MINUS_RANK                         5888
# NBA_FANTASY_PTS_RANK                   12464
# DD2_RANK                                2246
# TD3_RANK                                 118
# Name: 0, Length: 64, dtype: object

# %%
df.to_csv('nba_stats2.csv')
